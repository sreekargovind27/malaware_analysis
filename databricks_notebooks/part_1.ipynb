# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu

# %%
# !pip install torch-geometric

# %%
dbutils.library.restartPython()

# %%
import sys
import os

repo_root = "/Workspace/Users/arun.g.ghontale@gmail.com/malaware_analysis"
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

print(f"✅ Added {repo_root} to Python path")

# %%
import os
os.chdir("/Workspace/Users/arun.g.ghontale@gmail.com/malaware_analysis")
print(f"Changed to: {os.getcwd()}")

# %%
# %pwd

# %%
# !ls

# %%
from config import Config

# Verify the path
print(f"BASE_PATH: {Config.BASE_PATH}")
print(f"RAW_DIR: {Config.RAW_DIR_ORIGINAL}")

# %%
from analysis.stage1.run_stage1 import main

# %%
# Run complete Stage 1 pipeline
main()

# %%
from analysis.stage2.run_stage2 import main

# %%
# run stage 2
main()
